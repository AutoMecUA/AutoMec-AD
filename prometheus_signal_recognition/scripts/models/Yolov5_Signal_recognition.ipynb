# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 15368, done.
# remote: Counting objects: 100% (13/13), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 15368 (delta 1), reused 6 (delta 0), pack-reused 15355
# Receiving objects: 100% (15368/15368), 14.30 MiB | 5.44 MiB/s, done.
# Resolving deltas: 100% (10505/10505), done.

# %%
# %cd yolov5
# !pip install -r requirements.txt  # install
# Out:
# /content/yolov5
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 KB 19.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 KB 8.5 MB/s eta 0:00:00
# ...

# %% [markdown]
# **!!! Add Signals_all.zip inside the folder yolov5**
#
# **!!! Add dataset.yaml inside the folder yolov5**

# %%
# !unzip Signals_all.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: Signals_all/train/signal2023-02-18-21-02-03.jpg
#   inflating: Signals_all/train/signal2023-02-18-21-02-03.txt
#   inflating: Signals_all/train/signal2023-02-18-21-02-59.jpg
#   inflating: Signals_all/train/signal2023-02-18-21-02-59.txt
#   inflating: Signals_all/train/signal2023-02-18-21-03-21.jpg
#   inflating: Signals_all/train/signal2023-02-18-21-03-21.txt
#   inflating: Signals_all/train/signal2023-02-18-21-03-24.jpg
#   inflating: Signals_all/train/signal2023-02-18-21-03-24.txt
#   inflating: Signals_all/train/signal2023-02-18-21-03-29.jpg
#   inflating: Signals_all/train/signal2023-02-18-21-03-29.txt
#   inflating: Signals_all/train/signal2023-02-18-21-03-31.jpg
#   inflating: Signals_all/train/signal2023-02-18-21-03-31.txt
#   inflating: Signals_all/train/signal2023-02-18-21-03-34.jpg
#   inflating: Signals_all/train/signal2023-02-18-21-03-34.txt
#   inflating: Signals_all/train/signal2023-02-18-21-03-36.jpg
# ...

# %% [markdown]
# # Train

# %%
# !python train.py --img 640 --batch 80 --epochs 70 --data dataset.yaml --weights yolov5s.pt
# Out:
# train: weights=yolov5s.pt, cfg=, data=dataset.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=10, batch_size=14, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-134-g23c4923 Python-3.9.16 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
#
# ...

# %% [markdown]
# # Test

# %%
# !python val.py --data dataset.yaml --weights /content/yolov5/runs/train/exp/best.pt --img 640

# %% [markdown]
# # Inference

# %%
# !python detect.py --source signal7.jpg --weights runs/train/best.pt
# Out:
# detect: weights=['runs/train/best.pt'], source=signal7.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-134-g23c4923 Python-3.9.16 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7045186 parameters, 0 gradients, 15.9 GFLOPs
# image 1/1 /content/yolov5/signal7.jpg: 640x480 1 Bus_signal, 13.1ms
# Speed: 0.6ms pre-process, 13.1ms inference, 1.7ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp3
